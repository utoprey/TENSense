# %%
# %matplotlib qt5

import os
import re

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Merging Experiment_1 log in one CSV file

# %%
print('Type log filename:')
#Sasha__Tue-07-Mar-2023-12-01-33.txt
patient_log_filename = input()

try:
    experiment_log_file = open(f'../Experiment_1/data/Sasha/stimulation_logs/{patient_log_filename}')
    lines = list(filter(lambda x: 'Skipped' not in x, experiment_log_file.readlines()))
    
    pw = [int(re.search('pulse: (.+?)mcs', line).group(1)) for line in lines]
    freq = [int(re.search('freq: (.+?)Hz', line).group(1)) for line in lines]
    dur = [int(re.search('duration: (.+?)ms', line).group(1)) for line in lines]
    
    # We lost last trial for Sasha probable -1 is irrelevant for others
    df_to_append = pd.DataFrame([pw, freq, dur], index=['pulseWidth', 'frequency', 'duration']).T[:-1] 
    display(df_to_append)
finally:
    experiment_log_file.close()
# Out:
# Type log filename:
#  Sasha__Tue-07-Mar-2023-12-01-33.txt
#     pulseWidth  frequency  duration
# 0          200         95       250
# 1          200         95       250
# 2          100         95        50
# 3          200          8       500
# 4          200         50       500
# 5          100         30        50
# 6          200         30       250
# 7          100          8       500
# 8          400          8       500
# 9          200          8       250
# 10         200         30       500
# 11         100         95       500
# 12          50         95       500
# 13          50         30       500
# 14         200         95       500
# 15         200         95        50
# 16         200         50       250
# 17         200         15       250
# 18          50         15       250
# 19         400         95        50
# 20         100         95       250
# 21         400          8       250
# 22         100         30       500
# 23          50         30       250
# 24         400         50       250
# 25         400         95       500
# 26         100         50       250
# 27          50          8       250
# 28         400         15       250
# 29         400         30        50
# 30         400         50        50
# 31         400         30       500
# 32         100          8       250
# 33         200         30        50
# 34         200         50        50
# 35         400         95       250
# 36          50         95       250
# 37          50          8       500
# 38          50         50       250
# 39         100         30       250
# 40          50         30        50
# 41          50         50        50
# 42          50         95        50
# 43          50         15       500
# 44         200         15       500
# 45         100         15       250
# 46         100         50       500
# 47         400         15       500
# 48         400         50       500
# 49         100         50        50
# 50         400         30       250
# 51         100         15       500

# %% [markdown]
# # Analysis of sliders values

# %%
print('Type patient ID:')
patient_id = input()

MAPS_DIR = f'../PerceptMapper/perceptMap/{patient_id}/{patient_id}'

PATIENT_CSV_FILENAME = f'{patient_id}_allData.csv'
# Out:
# Type patient ID:
#  Sasha

# %%
patient_df = pd.read_csv(f'{MAPS_DIR}/{PATIENT_CSV_FILENAME}')
patient_df = pd.concat([patient_df, df_to_append], axis=1)
display(patient_df.head())

FIRST_PAGE_SLIDERS = ['naturalSlider', 'maintactileSlider', 'motorSlider']
# Grouping by each of three parameters frequency, pulse width, duration

# Frequency
patient_df_freq_mean = patient_df.groupby('frequency').mean()[FIRST_PAGE_SLIDERS]
patient_df_freq_std = patient_df.groupby('frequency').std()[FIRST_PAGE_SLIDERS]
patient_df_freq_count = patient_df.groupby('frequency').count()[FIRST_PAGE_SLIDERS]
ax = (patient_df_freq / patient_df_freq_count).plot.bar()
ax.grid()
ax.legend(title='Scores of', labels=['Intensity', 'Naturalness', 'Proprioception'], fontsize=18)
ax.get_legend().get_title().set_fontsize('20')
ax.set_ylabel('Average tactile intensity', fontsize=22)
ax.set_xlabel('Frequency(Hz)', fontsize=22)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=18, rotation=0)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)

# Pulse width
patient_df_pw_mean = patient_df.groupby('pulseWidth').mean()[FIRST_PAGE_SLIDERS]
patient_df_pw_std = patient_df.groupby('pulseWidth').std()[FIRST_PAGE_SLIDERS]
patient_df_pw_count = patient_df.groupby('pulseWidth').count()[FIRST_PAGE_SLIDERS]
ax = (patient_df_pw_mean / patient_df_pw_count).plot.bar()
ax.grid()
ax.legend(title='Scores of', labels=['Intensity', 'Naturalness', 'Proprioception'], fontsize=18)
ax.get_legend().get_title().set_fontsize('20')
ax.set_ylabel('Average tactile intensity', fontsize=22)
ax.set_xlabel('Frequency(Hz)', fontsize=22)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=18, rotation=0)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)

# Duration
patient_df_dur_mean = patient_df.groupby('duration').mean()[FIRST_PAGE_SLIDERS]
patient_df_dur_std = patient_df.groupby('duration').std()[FIRST_PAGE_SLIDERS]
patient_df_dur_count = patient_df.groupby('duration').count()[FIRST_PAGE_SLIDERS]
ax = (patient_df_dur_mean / patient_df_dur_count).plot.bar()
ax.grid()
ax.legend(title='Scores of', labels=['Intensity', 'Naturalness', 'Proprioception'], fontsize=18)
ax.get_legend().get_title().set_fontsize('20')
ax.set_ylabel('Average tactile intensity', fontsize=22)
ax.set_xlabel('Frequency(Hz)', fontsize=22)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=18, rotation=0)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# Out:
#    Picture      Time  naturalSlider  painSlider  phantomSlider  motorSlider  \
# 0        0  15:05:33            1.9         0.0            0.0          5.0
# 1        1  15:06:25            1.0         0.0            0.0          0.0
# 2        2  15:08:01           -3.0         0.0            0.0          8.0
# 3        3  15:11:47           -3.0         0.0            0.0          0.0
# 4        4  15:12:18            0.0         0.0            0.0          0.0
#
#    tempSlider  maintactileSlider  Vibration  Twitching  ...  Pulsation  \
# 0         1.9                6.1       True       True  ...       True
# 1         0.0                2.0       True       True  ...       True
# 2         1.9                8.0       True       True  ...       True
# 3         0.0                8.0       True       True  ...       True
# 4         0.0                0.0       True      False  ...       True
#
#    Tickling  Itching  Tingling  Numbness  Muscle contraction  Was Felt  \
# 0     False    False     False      True               False      True
# 1     False    False     False      True               False     False
# 2     False    False     False      True               False      True
# 3      True    False     False      True               False     False
# 4      True    False     False      True               False     False
#
#    pulseWidth  frequency  duration
# 0         200         95       250
# 1         200         95       250
# 2         100         95        50
# 3         200          8       500
# 4         200         50       500
#
# [5 rows x 27 columns]
# <ipython-input-93-e41aae1aaa68>:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# <ipython-input-93-e41aae1aaa68>:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# <ipython-input-93-e41aae1aaa68>:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# [Text(0, -0.30000000000000004, '−0.3'),
#  Text(0, -0.20000000000000004, '−0.2'),
#  Text(0, -0.10000000000000003, '−0.1'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.09999999999999998, '0.1'),
#  Text(0, 0.19999999999999996, '0.2'),
#  Text(0, 0.30000000000000004, '0.3'),
#  Text(0, 0.4, '0.4'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 0.6, '0.6')]

# %%
patient_df_pw_sum = patient_df.groupby('pulseWidth').sum()
patient_df_pw_count = patient_df.groupby('pulseWidth').count()
display(patient_df_pw_sum / patient_df_pw_count)
display(patient_df_pw_count)

actual_sliders = (patient_df_pw_sum / patient_df_pw_count)[['Electric Current', 'Hit', 'Intention to Make Movement', 'Itching',
       'Muscle contraction', 'Numbness', 'Prickling', 'Pulsation',
       'Puncture', 'Squeezing', 'Tickling', 'Time', 'Tingling', 'Touch',
       'Twitching', 'Vibration', 'Was Felt']]
actual_sliders.plot()
# Out:
#             Electric Current       Hit  Intention to Make Movement  Itching  \
# pulseWidth
# 50                       0.0  0.166667                    0.000000      0.0
# 100                      0.0  0.230769                    0.000000      0.0
# 200                      0.0  0.357143                    0.142857      0.0
# 400                      0.0  0.692308                    0.000000      0.0
#
#             Muscle contraction  Numbness    Picture  Prickling  Pulsation  \
# pulseWidth
# 50                         0.0  0.333333  30.833333   0.333333   0.416667
# 100                        0.0  0.692308  27.307692   0.692308   0.692308
# 200                        0.0  0.928571  14.714286   0.928571   1.000000
# 400                        0.0  1.000000  30.384615   1.000000   1.000000
#
#             Puncture  ...  Vibration  Was Felt    duration  frequency  \
# pulseWidth            ...
# 50               0.0  ...   0.250000  0.000000  283.333333  43.416667
# 100              0.0  ...   0.461538  0.307692  300.000000  43.923077
# 200              0.0  ...   0.928571  0.214286  296.428571  47.571429
# 400              0.0  ...   0.615385  0.076923  300.000000  43.923077
#
#             maintactileSlider  motorSlider  naturalSlider  painSlider  \
# pulseWidth
# 50                   5.391667     0.000000      -1.500000         0.0
# 100                  4.969231     1.838462      -0.369231         0.0
# 200                  5.792857     0.864286      -0.735714         0.0
# 400                  5.307692     0.223077      -2.053846         0.0
#
#             phantomSlider  tempSlider
# pulseWidth
# 50                    0.0    0.000000
# 100                   0.0    0.146154
# 200                   0.0    0.135714
# 400                   0.0    0.000000
#
# [4 rows x 26 columns]
#             Picture  Time  naturalSlider  painSlider  phantomSlider  \
# pulseWidth
# 50               12    12             12          12             12
# 100              13    13             13          13             13
# 200              14    14             14          14             14
# 400              13    13             13          13             13
#
#             motorSlider  tempSlider  maintactileSlider  Vibration  Twitching  \
# pulseWidth
# 50                   12          12                 12         12         12
# 100                  13          13                 13         13         13
# 200                  14          14                 14         14         14
# 400                  13          13                 13         13         13
#
#             ...  Hit  Pulsation  Tickling  Itching  Tingling  Numbness  \
# pulseWidth  ...
# 50          ...   12         12        12       12        12        12
# 100         ...   13         13        13       13        13        13
# 200         ...   14         14        14       14        14        14
# 400         ...   13         13        13       13        13        13
#
#             Muscle contraction  Was Felt  frequency  duration
# pulseWidth
# 50                          12        12         12        12
# 100                         13        13         13        13
# 200                         14        14         14        14
# 400                         13        13         13        13
#
# [4 rows x 26 columns]
# <AxesSubplot: xlabel='pulseWidth'>

# %%
patient_df_pw_sum
# Out:
#             Picture  naturalSlider  painSlider  phantomSlider  motorSlider  \
# pulseWidth
# 50              370          -18.0         0.0            0.0          0.0
# 100             355           -4.8         0.0            0.0         23.9
# 200             206          -10.3         0.0            0.0         12.1
# 400             395          -26.7         0.0            0.0          2.9
#
#             tempSlider  maintactileSlider  Vibration  Twitching  \
# pulseWidth
# 50                 0.0               64.7          3          5
# 100                1.9               64.6          6          9
# 200                1.9               81.1         13         13
# 400                0.0               69.0          8         13
#
#             Intention to Make Movement  ...  Hit  Pulsation  Tickling  \
# pulseWidth                              ...
# 50                                   0  ...    2          5         6
# 100                                  0  ...    3          9         5
# 200                                  2  ...    5         14         5
# 400                                  0  ...    9         13         3
#
#             Itching  Tingling  Numbness  Muscle contraction  Was Felt  \
# pulseWidth
# 50                0         0         4                   0         0
# 100               0         3         9                   0         4
# 200               0         2        13                   0         3
# 400               0         3        13                   0         1
#
#             frequency  duration
# pulseWidth
# 50                521      3400
# 100               571      3900
# 200               666      4150
# 400               571      3900
#
# [4 rows x 25 columns]

# %%
patient_df.groupby('pulseWidth')

# %%
patient_df_freq_sum = patient_df.groupby('frequency').sum()
patient_df_freq_count = patient_df.groupby('frequency').count()
display(patient_df_freq_sum / patient_df_freq_count)
display(patient_df_freq_count)

actual_sliders = (patient_df_freq_sum / patient_df_freq_count)[['Electric Current', 'Hit', 'Intention to Make Movement', 'Itching',
       'Muscle contraction', 'Numbness', 'Prickling', 'Pulsation',
       'Puncture', 'Squeezing', 'Tickling', 'Time', 'Tingling', 'Touch',
       'Twitching', 'Vibration', 'Was Felt']]
actual_sliders.plot()
# Out:
#            Electric Current       Hit  Intention to Make Movement  Itching  \
# frequency
# 8                       0.0  0.125000                    0.125000      0.0
# 15                      0.0  0.125000                    0.000000      0.0
# 30                      0.0  0.666667                    0.083333      0.0
# 50                      0.0  0.454545                    0.000000      0.0
# 95                      0.0  0.307692                    0.000000      0.0
#
#            Muscle contraction  Numbness    Picture  Prickling  Pulsation  \
# frequency
# 8                         0.0  0.875000  18.000000   0.875000   0.875000
# 15                        0.0  0.500000  36.625000   0.500000   0.750000
# 30                        0.0  0.750000  25.083333   0.833333   0.750000
# 50                        0.0  0.818182  32.363636   0.818182   0.818182
# 95                        0.0  0.769231  17.846154   0.692308   0.769231
#
#            Puncture  ...  Vibration  Was Felt    duration  maintactileSlider  \
# frequency            ...
# 8               0.0  ...   0.625000  0.125000  375.000000           6.962500
# 15              0.0  ...   0.375000  0.125000  375.000000           4.775000
# 30              0.0  ...   0.583333  0.083333  266.666667           5.333333
# 50              0.0  ...   0.727273  0.181818  245.454545           5.636364
# 95              0.0  ...   0.538462  0.230769  265.384615           4.576923
#
#            motorSlider  naturalSlider  painSlider  phantomSlider  pulseWidth  \
# frequency
# 8             0.387500      -1.225000         0.0            0.0  187.500000
# 15            0.950000      -1.875000         0.0            0.0  187.500000
# 30            0.575000      -1.000000         0.0            0.0  187.500000
# 50            0.572727      -2.272727         0.0            0.0  200.000000
# 95            1.153846       0.153846         0.0            0.0  188.461538
#
#            tempSlider
# frequency
# 8            0.000000
# 15           0.000000
# 30           0.000000
# 50           0.000000
# 95           0.292308
#
# [5 rows x 26 columns]
#            Picture  Time  naturalSlider  painSlider  phantomSlider  \
# frequency
# 8                8     8              8           8              8
# 15               8     8              8           8              8
# 30              12    12             12          12             12
# 50              11    11             11          11             11
# 95              13    13             13          13             13
#
#            motorSlider  tempSlider  maintactileSlider  Vibration  Twitching  \
# frequency
# 8                    8           8                  8          8          8
# 15                   8           8                  8          8          8
# 30                  12          12                 12         12         12
# 50                  11          11                 11         11         11
# 95                  13          13                 13         13         13
#
#            ...  Hit  Pulsation  Tickling  Itching  Tingling  Numbness  \
# frequency  ...
# 8          ...    8          8         8        8         8         8
# 15         ...    8          8         8        8         8         8
# 30         ...   12         12        12       12        12        12
# 50         ...   11         11        11       11        11        11
# 95         ...   13         13        13       13        13        13
#
#            Muscle contraction  Was Felt  pulseWidth  duration
# frequency
# 8                           8         8           8         8
# 15                          8         8           8         8
# 30                         12        12          12        12
# 50                         11        11          11        11
# 95                         13        13          13        13
#
# [5 rows x 26 columns]
# <AxesSubplot: xlabel='frequency'>

# %%
patient_df_dur_sum = patient_df.groupby('duration').sum()
patient_df_dur_count = patient_df.groupby('duration').count()
display(patient_df_dur_sum / patient_df_dur_count)
display(patient_df_dur_count)

actual_sliders = (patient_df_dur_sum / patient_df_dur_count)[['Electric Current', 'Hit', 'Intention to Make Movement', 'Itching',
       'Muscle contraction', 'Numbness', 'Prickling', 'Pulsation',
       'Puncture', 'Squeezing', 'Tickling', 'Time', 'Tingling', 'Touch',
       'Twitching', 'Vibration', 'Was Felt']]
actual_sliders.plot()
# Out:
#           Electric Current       Hit  Intention to Make Movement  Itching  \
# duration
# 50                     0.0  0.500000                    0.000000      0.0
# 250                    0.0  0.285714                    0.047619      0.0
# 500                    0.0  0.368421                    0.052632      0.0
#
#           Muscle contraction  Numbness    Picture  Prickling  Pulsation  \
# duration
# 50                       0.0  0.750000  28.250000   0.750000   0.750000
# 250                      0.0  0.809524  24.333333   0.809524   0.809524
# 500                      0.0  0.684211  25.052632   0.684211   0.789474
#
#           Puncture  ...  Vibration  Was Felt  frequency  maintactileSlider  \
# duration            ...
# 50             0.0  ...   0.583333  0.250000  58.333333           6.666667
# 250            0.0  ...   0.571429  0.190476  42.238095           5.761905
# 500            0.0  ...   0.578947  0.052632  39.052632           4.126316
#
#           motorSlider  naturalSlider  painSlider  phantomSlider  pulseWidth  \
# duration
# 50           1.433333      -2.833333         0.0            0.0  187.500000
# 250          0.671429      -1.000000         0.0            0.0  188.095238
# 500          0.400000      -0.252632         0.0            0.0  194.736842
#
#           tempSlider
# duration
# 50          0.158333
# 250         0.090476
# 500         0.000000
#
# [3 rows x 26 columns]
#           Picture  Time  naturalSlider  painSlider  phantomSlider  \
# duration
# 50             12    12             12          12             12
# 250            21    21             21          21             21
# 500            19    19             19          19             19
#
#           motorSlider  tempSlider  maintactileSlider  Vibration  Twitching  \
# duration
# 50                 12          12                 12         12         12
# 250                21          21                 21         21         21
# 500                19          19                 19         19         19
#
#           ...  Hit  Pulsation  Tickling  Itching  Tingling  Numbness  \
# duration  ...
# 50        ...   12         12        12       12        12        12
# 250       ...   21         21        21       21        21        21
# 500       ...   19         19        19       19        19        19
#
#           Muscle contraction  Was Felt  pulseWidth  frequency
# duration
# 50                        12        12          12         12
# 250                       21        21          21         21
# 500                       19        19          19         19
#
# [3 rows x 26 columns]
# <AxesSubplot: xlabel='duration'>
